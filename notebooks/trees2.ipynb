# %%
import csv

# %%
with open ('../data/trees.csv', newline='') as csvfile:
    trees_reader = csv.reader(csvfile, delimiter=',')
    list_trees = []
    for row in trees_reader:
        list_trees.append(row)

# %%
list_trees[0]
# Out:
# ['\ufeffELEM_POINT_ID',
#  'CODE',
#  'NOM',
#  'GENRE',
#  'GENRE_DESC',
#  'CATEGORIE',
#  'CATEGORIE_DESC',
#  'SOUS_CATEGORIE',
#  'SOUS_CATEGORIE_DESC',
#  'CODE_PARENT',
#  'CODE_PARENT_DESC',
#  'ADR_SECTEUR',
#  'BIEN_REFERENCE',
#  'GENRE_BOTA',
#  'ESPECE',
#  'VARIETE',
#  'STADEDEDEVELOPPEMENT',
#  'EQUIPE',
#  'REMARQUES',
#  'ANNEEDEPLANTATION',
#  'RAISONDEPLANTATION',
#  'TRAITEMENTCHENILLES',
#  'COURRIER',
#  'IDENTIFIANTPLU',
#  'TYPEIMPLANTATIONPLU',
#  'INTITULEPROTECTIONPLU',
#  'ANNEEABATTAGE',
#  'ESSOUCHEMENT',
#  'DIAMETREARBRE',
#  'CAUSEABATTAGE',
#  'COLLECTIVITE',
#  'GeoJSON']

# %% [markdown]
# # Genre botanique

# %%
genre_bota = [list_trees[i][13] for i in range(1, len(list_trees))]
genre_bota[1:50]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  'Platanus',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Platanus']

# %%
genre_bota_unique = set(genre_bota)
genre_bota_unique
# Out:
# {'',
#  'Abies',
#  'Acer',
#  'Aesculus',
#  'Ailanthus',
#  'Albizia',
#  'Alnus',
#  'Amélanchier',
#  'Araucaria',
#  'Betula',
#  'Broussonetia',
#  'Buxus',
#  'Calocedrus',
#  'Carpinus',
#  'Castanea',
#  'Catalpa',
#  'Cedrela',
#  'Cedrus',
#  'Celtis',
#  'Cephalotaxus',
#  'Cercidiphyllum',
#  'Cercis',
#  'Chamaecyparis',
#  'Chimonanthus',
#  'Chionanthus',
#  'Chitalpa',
#  'Cladastris',
#  'Clerodendron',
#  'Cornus',
#  'Corylus',
#  'Cotinus',
#  'Crataegus',
#  'Cryptomeria',
#  'Cupressocyparis',
#  'Cupressus',
#  'Cydonia',
#  'Davidia',
#  'Diospyros',
#  'Eleagnus',
#  'Eriobotrya ',
#  'Eucalyptus',
#  'Fagus',
#  'Ficus',
#  'Fontanesia',
#  'Fraxinus',
#  'Ginkgo',
#  'Gleditsia',
#  'Gymnocladus',
#  'Halesia',
#  'Hovenia',
#  'Ilex',
#  'Juglans',
#  'Juniperus',
#  'Koelreuteria',
#  'Laburnum',
#  'Lagerstroemia',
#  'Larix',
#  'Libocedrus',
#  'Ligustrum',
#  'Liquidambar',
#  'Liriodendron',
#  'Lonicera',
#  'Maclura',
#  'Magnolia',
#  'Malus',
# ...

# %%
espece = [list_trees[i][14] for i in range(1, len(list_trees))]

# %%
espece_unique = set(espece)
espece_unique
# Out:
# {'',
#  'abies',
#  'acerifolia',
#  'acutissima',
#  'alaternus',
#  'alba',
#  'alnifolia',
#  'altissima',
#  'americana',
#  'amurense',
#  'amurensis',
#  'amygdaliformis',
#  'amygdalus',
#  'anagynoides',
#  'angustifolia',
#  'aquifolium',
#  'aria',
#  'arizonica',
#  'armeniaca',
#  'atlantica',
#  'aucuparia',
#  'auricularis',
#  'australis',
#  'avellana',
#  'avium',
#  'babylonica',
#  'baccata',
#  'betulus',
#  'bignonoides',
#  'biloba',
#  'bombycis',
#  'buergerianum',
#  'bumalda',
#  'calleryana',
#  'campanulata',
#  'campestre',
#  'canadensis',
#  'capillipes',
#  'cappadocicum',
#  'caprea',
#  'carica',
#  'carnea',
#  'carolina',
#  'carpinifolia',
#  'castaneifolia',
#  'cerasifera',
#  'cerasus',
#  'cerris',
#  'chamaemespilus',
#  'chandelle seche',
#  'chinensis',
#  'coccinea',
#  'coggygria',
#  'colurna',
#  'communis',
#  'concolor',
#  'controversa',
#  'cordata',
#  'coronaria',
#  'crenata',
#  'crus-galli',
#  'cuspidata',
#  'danielli',
# ...

# %%
genre_espece = [(b, e) for b, e in zip(genre_bota, espece)]
genre_espece[50:80]
# Out:
# [('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('Platanus', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('', ''),
#  ('Ginkgo', 'biloba'),
#  ('Salix', ''),
#  ('Liriodendron', 'tulipifera'),
#  ('Liriodendron', 'tulipifera'),
#  ('Liriodendron', 'tulipifera'),
#  ('Catalpa', 'bignonoides'),
#  ('Platanus', 'acerifolia'),
#  ('Platanus', 'acerifolia'),
#  ('Platanus', 'acerifolia'),
#  ('Platanus', 'acerifolia')]

# %%
test = set(genre_espece)
test
# Out:
# {('', ''),
#  ('Abies', 'concolor'),
#  ('Abies', 'koreana'),
#  ('Abies', 'nordmaniana'),
#  ('Abies', 'pinsapo'),
#  ('Acer', ''),
#  ('Acer', 'buergerianum'),
#  ('Acer', 'campestre'),
#  ('Acer', 'capillipes'),
#  ('Acer', 'cappadocicum'),
#  ('Acer', 'carpinifolia'),
#  ('Acer', 'davidii'),
#  ('Acer', 'freemanii'),
#  ('Acer', 'ginnala'),
#  ('Acer', 'griseum'),
#  ('Acer', 'grosseri'),
#  ('Acer', 'heldreichii'),
#  ('Acer', 'hippocastanum'),
#  ('Acer', 'japonicum'),
#  ('Acer', 'monspessulanum'),
#  ('Acer', 'negundo'),
#  ('Acer', 'nikoense'),
#  ('Acer', 'opalus'),
#  ('Acer', 'palmatum'),
#  ('Acer', 'platanoides'),
#  ('Acer', 'pseudoplatanus'),
#  ('Acer', 'rubrum'),
#  ('Acer', 'saccharinum'),
#  ('Acer', 'tartarica'),
#  ('Acer', 'triflorum'),
#  ('Acer', 'utilis'),
#  ('Acer', 'zoeschense'),
#  ('Aesculus', 'carnea'),
#  ('Aesculus', 'chandelle seche'),
#  ('Aesculus', 'hippocastanum'),
#  ('Aesculus', 'parviflora'),
#  ('Aesculus', 'pavia'),
# ...

# %% [markdown]
# # Count genre_bota with dict

# %%
count_bota = dict([])
for g in genre_bota:
    if g not in count_bota.keys():
        count_bota.update({ g : 1})
    else:
        count_bota[g] = count_bota[g] + 1

# %%
count_bota
# Out:
# {'': 515,
#  'Platanus': 4663,
#  'Ginkgo': 111,
#  'Salix': 143,
#  'Liriodendron': 507,
#  'Catalpa': 89,
#  'Pyrus': 501,
#  'Robinia': 287,
#  'Acer': 5276,
#  'Zelkova': 233,
#  'Parrotia': 54,
#  'Fraxinus': 1506,
#  'Fagus': 267,
#  'Magnolia': 409,
#  'Taxus': 202,
#  'Alnus': 826,
#  'Picea': 252,
#  'Cupressus': 203,
#  'Sequoiadendron': 14,
#  'Pinus': 2118,
#  'Betula': 1247,
#  'Tilia': 1770,
#  'Cedrus': 407,
#  'Populus': 966,
#  'Celtis': 193,
#  'Thuja': 48,
#  'Sorbus': 88,
#  'Sophora': 426,
#  'Liquidambar': 809,
#  'Prunus': 996,
#  'Calocedrus': 4,
#  'Paulownia': 101,
#  'Gymnocladus': 9,
#  'Ulmus': 210,
#  'Corylus': 174,
#  'Morus': 100,
#  'Clerodendron': 5,
#  'Gleditsia': 352,
#  'Libocedrus': 47,
#  'Quercus': 677,
#  'Lagerstroemia': 50,
#  'Taxodium': 9,
#  'Amélanchier': 96,
#  'Cercidiphyllum': 7,
#  'Ilex': 24,
#  'Malus': 262,
#  'Cedrela': 46,
#  'Photinia': 10,
#  'Tetradium': 88,
#  'Koelreuteria': 271,
#  'Halesia': 9,
#  'Crataegus': 108,
# ...

# %% [markdown]
# # Correction

# %%
d = {k:genre_bota.count(k) for k in set(genre_bota)}

# %% [markdown]
# # list unique genre_bota

# %%
count_bota.keys()
# Out:
# dict_keys(['', 'Platanus', 'Ginkgo', 'Salix', 'Liriodendron', 'Catalpa', 'Pyrus', 'Robinia', 'Acer', 'Zelkova', 'Parrotia', 'Fraxinus', 'Fagus', 'Magnolia', 'Taxus', 'Alnus', 'Picea', 'Cupressus', 'Sequoiadendron', 'Pinus', 'Betula', 'Tilia', 'Cedrus', 'Populus', 'Celtis', 'Thuja', 'Sorbus', 'Sophora', 'Liquidambar', 'Prunus', 'Calocedrus', 'Paulownia', 'Gymnocladus', 'Ulmus', 'Corylus', 'Morus', 'Clerodendron', 'Gleditsia', 'Libocedrus', 'Quercus', 'Lagerstroemia', 'Taxodium', 'Amélanchier', 'Cercidiphyllum', 'Ilex', 'Malus', 'Cedrela', 'Photinia', 'Tetradium', 'Koelreuteria', 'Halesia', 'Crataegus', 'Aesculus', 'Ptelea', 'Chimonanthus', 'Carpinus', 'Metasequoia', 'Cercis', 'Cornus', 'Juglans', 'Pteroceltis', 'Broussonetia', 'Phellodendron', 'Cupressocyparis', 'Cydonia', 'Ficus', 'Eleagnus', 'Lonicera', 'Albizia', 'Pterocarya', 'Davidia', 'Buxus', 'Cladastris', 'Chionanthus', 'Syringa', 'Abies', 'Sterculia', 'Phillyrea', 'Ailanthus', 'Olea', 'Sambucus', 'Chamaecyparis', 'Fontanesia'
# ...

# %% [markdown]
# # Order genre_bota by number

# %%
#list(count_bota.items()
sort_genre_bota = sorted(count_bota.items(), key = lambda x : x[1], reverse=True)
sort_genre_bota
# Out:
# [('Acer', 5276),
#  ('Platanus', 4663),
#  ('Pinus', 2118),
#  ('Tilia', 1770),
#  ('Fraxinus', 1506),
#  ('Carpinus', 1296),
#  ('Betula', 1247),
#  ('Prunus', 996),
#  ('Populus', 966),
#  ('Alnus', 826),
#  ('Liquidambar', 809),
#  ('Quercus', 677),
#  ('', 515),
#  ('Liriodendron', 507),
#  ('Pyrus', 501),
#  ('Aesculus', 459),
#  ('Sophora', 426),
#  ('Magnolia', 409),
#  ('Cedrus', 407),
#  ('Chamaecyparis', 373),
#  ('Gleditsia', 352),
#  ('Cercis', 351),
#  ('Robinia', 287),
#  ('Koelreuteria', 271),
#  ('Fagus', 267),
#  ('Malus', 262),
#  ('Picea', 252),
#  ('Zelkova', 233),
#  ('Ulmus', 210),
#  ('Cupressus', 203),
#  ('Taxus', 202),
#  ('Celtis', 193),
#  ('Corylus', 174),
#  ('Salix', 143),
#  ('Ginkgo', 111),
#  ('Crataegus', 108),
#  ('Paulownia', 101),
#  ('Morus', 100),
#  ('Cupressocyparis', 100),
#  ('Amélanchier', 96),
#  ('Catalpa', 89),
#  ('Sorbus', 88),
#  ('Tetradium', 88),
#  ('Metasequoia', 81),
#  ('Ailanthus', 80),
#  ('Albizia', 67),
#  ('Juglans', 66),
# ...

# %% [markdown]
# # Most represented genre_bota

# %%
sum(count_bota.values())
# Out:
# 31243

# %%
max(count_bota.values())
# Out:
# 5276

# %%
def get_key(my_dict, val):
    searched_key = None
    for key, value in my_dict.items():
         if val == value:
            searched_key = key
    return searched_key

# %%
ratio_mostrepr = max(count_bota.values()) / sum(count_bota.values())
ratio_mostrepr
# Out:
# 0.16886982684121243

# %% [markdown]
# # Ratio all bota

# %%
get_key(count_bota, max(count_bota.values()))
# Out:
# 'Acer'

# %%
sum_ratio = 0
for key, val in count_bota.items():
    ratio = val / sum(count_bota.values()) * 100
    sum_ratio += ratio
    print('{},\t\t ratio = {:.1f} %'.format(key, ratio))
print(sum_ratio)
# Out:
# ,		 ratio = 1.6 %
# Platanus,		 ratio = 14.9 %
# Ginkgo,		 ratio = 0.4 %
# Salix,		 ratio = 0.5 %
# Liriodendron,		 ratio = 1.6 %
# Catalpa,		 ratio = 0.3 %
# Pyrus,		 ratio = 1.6 %
# Robinia,		 ratio = 0.9 %
# Acer,		 ratio = 16.9 %
# Zelkova,		 ratio = 0.7 %
# Parrotia,		 ratio = 0.2 %
# Fraxinus,		 ratio = 4.8 %
# Fagus,		 ratio = 0.9 %
# Magnolia,		 ratio = 1.3 %
# Taxus,		 ratio = 0.6 %
# Alnus,		 ratio = 2.6 %
# Picea,		 ratio = 0.8 %
# Cupressus,		 ratio = 0.6 %
# Sequoiadendron,		 ratio = 0.0 %
# Pinus,		 ratio = 6.8 %
# Betula,		 ratio = 4.0 %
# Tilia,		 ratio = 5.7 %
# Cedrus,		 ratio = 1.3 %
# Populus,		 ratio = 3.1 %
# Celtis,		 ratio = 0.6 %
# Thuja,		 ratio = 0.2 %
# Sorbus,		 ratio = 0.3 %
# Sophora,		 ratio = 1.4 %
# Liquidambar,		 ratio = 2.6 %
# Prunus,		 ratio = 3.2 %
# Calocedrus,		 ratio = 0.0 %
# Paulownia,		 ratio = 0.3 %
# Gymnocladus,		 ratio = 0.0 %
# Ulmus,		 ratio = 0.7 %
# Corylus,		 ratio = 0.6 %
# Morus,		 ratio = 0.3 %
# Clerodendron,		 ratio = 0.0 %
# ...

# %% [markdown]
# # Diversity

# %% [markdown]
# Goal: not more than 20% of a genre, not more than 10% of a species

# %% [markdown]
# The most represented kind is Acer with 17% => it's ok

# %% [markdown]
# The most represented species is Platanus acerifolia with 14% => not ok

# %% [markdown]
# ## Count genre, species

# %%
tree
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 tree
#
# NameError: name 'tree' is not defined

# %%
especes = set( [" ".join([row[13], row[14]]) for row in list_trees])
especes
# Out:
# {' ',
#  'Abies concolor',
#  'Abies koreana',
#  'Abies nordmaniana',
#  'Abies pinsapo',
#  'Acer ',
#  'Acer buergerianum',
#  'Acer campestre',
#  'Acer capillipes',
#  'Acer cappadocicum',
#  'Acer carpinifolia',
#  'Acer davidii',
#  'Acer freemanii',
#  'Acer ginnala',
#  'Acer griseum',
#  'Acer grosseri',
#  'Acer heldreichii',
#  'Acer hippocastanum',
#  'Acer japonicum',
#  'Acer monspessulanum',
#  'Acer negundo',
#  'Acer nikoense',
#  'Acer opalus',
#  'Acer palmatum',
#  'Acer platanoides',
#  'Acer pseudoplatanus',
#  'Acer rubrum',
#  'Acer saccharinum',
#  'Acer tartarica',
#  'Acer triflorum',
#  'Acer utilis',
#  'Acer zoeschense',
#  'Aesculus carnea',
#  'Aesculus chandelle seche',
#  'Aesculus hippocastanum',
#  'Aesculus parviflora',
#  'Aesculus pavia',
#  'Ailanthus altissima',
#  'Albizia jullibrissin',
#  'Alnus ',
#  'Alnus cordata',
#  'Alnus glutinosa',
#  'Alnus incana',
#  'Alnus spaethii',
#  'Amélanchier alnifolia',
#  'Amélanchier canadensis',
# ...

# %%
# Out:
# False

# %%
#
# Out:
# {'': {'': 0,
#   'strobus': 0,
#   'coccinea': 0,
#   'carnea': 0,
#   'freemanii': 0,
#   'yedoensis': 0,
#   'cappadocicum': 0,
#   'padus': 0,
#   'sylvatica': 0,
#   'platanor': 0,
#   'chamaemespilus': 0,
#   'floribunda': 0,
#   'typhina': 0,
#   'resista': 0,
#   'soulangeana': 0,
#   'pavia': 0,
#   'utilis': 0,
#   'tatarinowii': 0,
#   'pungens': 0,
#   'mariesii': 0,
#   'mongolica': 0,
#   'subhirtella': 0,
#   'laevigata': 0,
#   'glutinosa': 0,
#   'alaternus': 0,
#   'grandiflora': 0,
#   'palmatum': 0,
#   'griseum': 0,
#   'spaethii': 0,
#   'laevis': 0,
#   'cerris': 0,
#   'cuspidata': 0,
#   'paniculata': 0,
#   'giganteum': 0,
#   'purpurea': 0,
#   'robur': 0,
#   'mas': 0,
#   'latifolia': 0,
#   'amurense': 0,
#   'florida': 0,
#   'laurocerasus': 0,
#   'myrsinifolia': 0,
#   'pseudoplatanus': 0,
#   'pisifera': 0,
#   'bumalda': 0,
#   'persica': 0,
#   'lavallei': 0,
#   'virginiacus': 0,
#   'crenata': 0,
#   'pumila': 0,
#   'australis': 0,
# ...

# %%
dict_genre_especes = {}
for g, e in zip(genre_bota, espece):
    if g not in dict_genre_especes.keys():
        count_espece = {e : 1}
        dict_genre_especes[g] = count_espece
    
    else:
        if e in dict_genre_especes[g].keys():
             dict_genre_especes[g][e] += 1
        else:
             dict_genre_especes[g][e] = 1

# %%
dict_genre_especes['Fraxinus']
# Out:
# {'excelsior': 776,
#  'ornus': 113,
#  'angustifolia': 165,
#  'americana': 113,
#  'sieboldiana': 19,
#  'pensylvanica': 24,
#  'mandshurica': 18,
#  'quadrangulata': 1,
#  'velutina': 54,
#  'mariesii': 7,
#  '': 39,
#  'oxycarpa': 177}

# %%
len(dict_genre_especes.keys())
# Out:
# 113

# %%
len(genre_bota)
# Out:
# 31243

# %%
for key, dic in dict_genre_especes.items():
    for k, val in dic.items():
        ratio = val / 31243 * 100
        print('{} {}, ratio = {:.1f} %'.format(key, k, ratio) )
# Out:
#  , ratio = 1.6 %
# Platanus , ratio = 0.2 %
# Platanus acerifolia, ratio = 14.2 %
# Platanus platanor, ratio = 0.3 %
# Platanus orientalis, ratio = 0.3 %
# Ginkgo biloba, ratio = 0.4 %
# Salix , ratio = 0.2 %
# Salix viminalis, ratio = 0.0 %
# Salix triandra, ratio = 0.0 %
# Salix purpurea, ratio = 0.0 %
# Salix caprea, ratio = 0.0 %
# Salix alba, ratio = 0.2 %
# Salix matsudana, ratio = 0.0 %
# Salix babylonica, ratio = 0.0 %
# Salix rosmarinifolia, ratio = 0.0 %
# Salix sepulcralis, ratio = 0.0 %
# Liriodendron tulipifera, ratio = 1.6 %
# Liriodendron , ratio = 0.0 %
# Catalpa bignonoides, ratio = 0.3 %
# Pyrus , ratio = 0.0 %
# Pyrus calleryana, ratio = 1.4 %
# Pyrus amygdaliformis, ratio = 0.0 %
# Pyrus communis, ratio = 0.1 %
# Pyrus salicifolia, ratio = 0.0 %
# Pyrus elaeagnifolia, ratio = 0.0 %
# Pyrus nivalis, ratio = 0.0 %
# Robinia pseudoacacia, ratio = 0.9 %
# Robinia platanoides, ratio = 0.0 %
# Robinia , ratio = 0.0 %
# Robinia altissima, ratio = 0.0 %
# ...

# %% [markdown]
# # Diversity over time

# %%
plantation_yr = [list_trees[i][19] for i in range(1, len(list_trees))]
unique_yr = set(plantation_yr)

# %%
# nested_dict = {}
# for y, b in zip(plantation_yr, genre_bota):
#     if y not in nested_dict.keys():
#         count_bota = {}
#         if b not in count_bota.keys():
#             count_bota.update({b : 1})
#         else:
#             count_bota[b] += 1
            
#         nested_dict.update({y : count_bota})
        
#     else:
#         if b not in nested_dict.get(y).keys():
#             nested_dict.get(y).update({b : 1})
#         else:
#             nested_dict.get(y)[b] += 1

# %%
nested_dict = {}
for y, b in zip(plantation_yr, genre_bota):
    if y not in nested_dict.keys():
        count_bota = {b : 1}
        nested_dict[y] = count_bota
        
    else:
        if b not in nested_dict.get(y).keys():
            nested_dict[y][b] = 1
        else:
            nested_dict[y][b] += 1

# %%
nested_dict.keys()
# Out:
# dict_keys(['', '2017', '2000', '2009', '1983', '1976', '2015', '2008', '1966', '1995', '1970', '2006', '2011', '2007', '2002', '1981', '1974', '1986', '2014', '1975', '2012', '1980', '2004', '1965', '1979', '1999', '2013', '2010', '1991', '1996', '2001', '1990', '1978', '1984', '1961', '1989', '1998', '1982', '1987', '1997', '2016', '1988', '1994', '1993', '1992', '2003', '1985', '2005', '1969', '1968', '1950', '1972', '1977', '1960', '1967', '1955', '1964', '1971', '1973'])

# %%
sort_nested_dict = sorted(nested_dict.items())
# yr_range = list(range(1990, 2017))
# print(yr_range)
# for k in yr_range:
#     print(nested_dict[str(k)])
type(sort_nested_dict)
# Out:
# list

# %%
nested_dict['2015']
# Out:
# {'Acer': 113,
#  'Zelkova': 32,
#  'Tilia': 17,
#  'Alnus': 50,
#  'Fraxinus': 70,
#  'Ulmus': 9,
#  'Amélanchier': 11,
#  'Metasequoia': 2,
#  'Prunus': 131,
#  'Malus': 34,
#  'Cercis': 7,
#  'Pyrus': 39,
#  'Sorbus': 17,
#  '': 6,
#  'Cornus': 10,
#  'Quercus': 72,
#  'Corylus': 19,
#  'Juglans': 6,
#  'Pinus': 27,
#  'Salix': 18,
#  'Pteroceltis': 9,
#  'Carpinus': 42,
#  'Phellodendron': 9,
#  'Cydonia': 3,
#  'Gleditsia': 4,
#  'Tetradium': 12,
#  'Cedrus': 3,
#  'Cladastris': 14,
#  'Liquidambar': 18,
#  'Chionanthus': 17,
#  'Liriodendron': 5,
#  'Syringa': 13,
#  'Celtis': 36,
#  'Rhamnus': 1,
#  'Laburnum': 8,
#  'Pterocarya': 3,
#  'Davidia': 3,
#  'Parrotia': 4,
#  'Cedrela': 2,
#  'Diospyros': 2,
#  'Pterostyrax': 3,
#  'Libocedrus': 7,
#  'Koelreuteria': 20,
#  'Gymnocladus': 1,
#  'Sophora': 7,
#  'Ficus': 1,
#  'Crataegus': 16,
#  'Lagerstroemia': 3,
#  'Sambucus': 3,
#  'Pistacia': 4,
#  'Magnolia': 13,
#  'Betula': 9,
#  'Styrax': 3,
#  'Fagus': 1,
#  'Ilex': 3,
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar([int(k) if k != ""  else 1900 for k in nested_dict.keys()], [len(v.keys()) for v in nested_dict.values()])
ax.set_xlim(left = 1950)
ax.set_xlabel('Year')
ax.set_ylabel('Number of planted species')
# Out:
# Text(0, 0.5, 'Number of planted species')

# %% [markdown]
# ## Plot number of species/total planted trees per year

# %%
plantation_yr = [list_trees[i][19] for i in range(1, len(list_trees))]

# %%
planted_trees = [int(y) for y in plantation_yr if not y == ""]

# %%
unique_years = set(planted_trees)

# %%
unique_yr_with_lostyr = set([int(k) for k in plantation_yr if k !=""])
#unique_yr_with_lostyr = set([int(k) if k != ""  else 1900 for k in plantation_yr])

# %%
nested_dict['1900'] = nested_dict.pop('')
ordered_nested_d = {}
for y in unique_yr_with_lostyr:
        ordered_nested_d[y] = nested_dict[str(y)]

# %%
trees_per_yr_counts = [plantation_yr.count(str(y)) for y in unique_yr_with_lostyr]

# %%
planted_species_yr = [len(v.keys()) for v in ordered_nested_d.values()]

# %%
fig, ax = plt.subplots()
ax.bar([int(y) for y in unique_yr_with_lostyr],  [int(a) / int(b) if int(b) !=0 else 0 for a, b in zip(planted_species_yr, trees_per_yr_counts)])
ax.set_xlim(left = 1950)
ax.set_xlabel('Year')
ax.set_ylabel('Number of planted species / \n number of planted trees')
# Out:
# Text(0, 0.5, 'Number of planted species / \n number of planted trees')

# %% [markdown]
# # End - the rest is random testing

# %%
len([len(v.keys()) for v in nested_dict.values()])
# Out:
# 59

# %%
len(trees_per_yr_counts)
# Out:
# 58

# %%
len(unique_years)
# Out:
# 58

# %%
len([int(a) / int(b) if int(b) !=0 else 0 for a, b in zip(planted_species_yr, trees_per_yr_counts)])
# Out:
# 59

# %%
import numpy as np
np.asarray(planted_species_yr) / np.asarray(trees_per_yr_counts)
# Out:
# /tmp/ipykernel_2821/2324060317.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   np.asarray(planted_species_yr) / np.asarray(trees_per_yr_counts)
# array([7.10900474e-03, 4.69696970e-01, 4.02684564e-02, 1.77777778e+00,
#        5.14285714e+00, 5.52631579e-02, 6.21052632e-01, 4.73684211e-01,
#        1.81034483e-01, 9.14285714e-02, 3.39335180e-02, 5.20000000e-01,
#        1.34615385e-01, 6.17647059e-01, 6.28571429e-02, 9.17899031e-03,
#        1.02880658e-02, 3.57142857e-02, 6.68859649e-02, 1.49584488e-01,
#        2.42146597e-02, 7.91925466e-02, 7.81250000e-02, 1.11111111e-01,
#        3.75375375e-02, 4.04040404e-02, 1.47058824e-01, 4.66926070e-02,
#        7.89473684e-02, 9.77198697e-02, 6.69745958e-02, 1.71232877e-01,
#        1.28318584e-01, 1.98757764e-01, 3.47222222e-03, 3.58514725e-02,
#        4.93506494e-02, 1.55462185e-01, 1.40909091e-01, 2.81923715e-02,
#        8.67678959e-02, 9.84009840e-03, 7.62463343e-02, 7.38636364e-02,
# ...

# %%
print([(y, t, b) for y, t, b in zip(unique_yr_with_lostyr, trees_per_yr_counts, planted_species_yr) if (int(y) >= 1960 and int(y) <= 1965)])
# Out:
# [(1960, 745, 30), (1961, 27, 48), (1964, 7, 36), (1965, 760, 42)]

# %%
plantation_yr.count('1961')
# Out:
# 27

# %%
nested_dict['1961']
# Out:
# {'Populus': 27}

# %%
len(nested_dict['1961'])
# Out:
# 1

# %%
nested_dict.keys()
# Out:
# dict_keys(['', '2017', '2000', '2009', '1983', '1976', '2015', '2008', '1966', '1995', '1970', '2006', '2011', '2007', '2002', '1981', '1974', '1986', '2014', '1975', '2012', '1980', '2004', '1965', '1979', '1999', '2013', '2010', '1991', '1996', '2001', '1990', '1978', '1984', '1961', '1989', '1998', '1982', '1987', '1997', '2016', '1988', '1994', '1993', '1992', '2003', '1985', '2005', '1969', '1968', '1950', '1972', '1977', '1960', '1967', '1955', '1964', '1971', '1973'])

# %%
[(v.keys(), len(v.keys())) for v in nested_dict.values()]
# Out:
# [(dict_keys(['', 'Fraxinus', 'Platanus']), 3),
#  (dict_keys(['', 'Platanus', 'Salix', 'Pyrus', 'Robinia', 'Prunus', 'Quercus', 'Lagerstroemia', 'Acer', 'Pinus', 'Parrotia', 'Fraxinus', 'Malus', 'Cercis', 'Liriodendron', 'Pterocarya', 'Betula', 'Zelkova', 'Picea', 'Syringa', 'Sophora', 'Gleditsia', 'Juglans', 'Ulmus', 'Diospyros', 'Chamaecyparis', 'Cedrus', 'Tilia', 'Carpinus', 'Chionanthus', 'Catalpa']),
#   31),
#  (dict_keys(['Ginkgo', 'Celtis', 'Amélanchier', 'Acer', 'Tilia', 'Alnus', 'Pinus', 'Fagus', 'Betula', 'Paulownia', 'Liquidambar', 'Cedrus', 'Quercus', 'Pyrus', 'Prunus', 'Carpinus', 'Koelreuteria', 'Magnolia', 'Fraxinus', 'Albizia', 'Corylus', 'Laburnum', 'Malus', 'Cercis', 'Platanus', 'Cupressus', 'Trachycarpus', 'Ailanthus', 'Aesculus', 'Parrotia']),
#   30),
# ...

# %%
# Out:
#   Input In [71]
#     def func_test(str(a)):
#                      ^
# SyntaxError: invalid syntax

# %%
unique_yr_with_lostyr
# Out:
# {1900,
#  1950,
#  1955,
#  1960,
#  1961,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017}

# %%
for y in unique_yr_with_lostyr:
    print(y)
# Out:
# 1950
# 1955
# 1960
# 1961
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 1900

# %%
len(nested_dict['1960'])
# Out:
# 48

# %%
nested_dict.keys()
# Out:
# dict_keys(['', '2017', '2000', '2009', '1983', '1976', '2015', '2008', '1966', '1995', '1970', '2006', '2011', '2007', '2002', '1981', '1974', '1986', '2014', '1975', '2012', '1980', '2004', '1965', '1979', '1999', '2013', '2010', '1991', '1996', '2001', '1990', '1978', '1984', '1961', '1989', '1998', '1982', '1987', '1997', '2016', '1988', '1994', '1993', '1992', '2003', '1985', '2005', '1969', '1968', '1950', '1972', '1977', '1960', '1967', '1955', '1964', '1971', '1973'])

# %%
type(nested_dict.keys())
# Out:
# dict_keys

# %%
int(list(nested_dict.keys()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 int(list(nested_dict.keys()))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
[int(k) if k != ""  else 1900 for k in nested_dict.keys()]
# Out:
# [1900,
#  2017,
#  2000,
#  2009,
#  1983,
#  1976,
#  2015,
#  2008,
#  1966,
#  1995,
#  1970,
#  2006,
#  2011,
#  2007,
#  2002,
#  1981,
#  1974,
#  1986,
#  2014,
#  1975,
#  2012,
#  1980,
#  2004,
#  1965,
#  1979,
#  1999,
#  2013,
#  2010,
#  1991,
#  1996,
#  2001,
#  1990,
#  1978,
#  1984,
#  1961,
#  1989,
#  1998,
#  1982,
#  1987,
#  1997,
#  2016,
#  1988,
#  1994,
#  1993,
#  1992,
#  2003,
#  1985,
#  2005,
#  1969,
#  1968,
#  1950,
#  1972,
#  1977,
#  1960,
#  1967,
#  1955,
#  1964,
#  1971,
#  1973]
